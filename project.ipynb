# %%
import pandas as pd
import os
import glob
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from imblearn.over_sampling import RandomOverSampler
from imblearn.pipeline import Pipeline

# %%
# Need to read in all of the data from the files. Using glob we can get the paths to the files. 
df_all = []
for f in glob.glob("crime data/*/*.csv"):
    df_all.append(pd.read_csv(f))

# Combine the list of dataframes
df_all = pd.concat(df_all,axis=0)

# Remove any of the rows that contain NAs
df_all = df_all[df_all['Last outcome category'].notna()]

# Need to convert these outcomes to be True or False to create a model that will classify if an offender is prossicuted
df_all['prosecuted'] = np.where(df_all['Last outcome category'].isin(["Offender given community sentence", "Offender sent to prison", "Offender given suspended prison sentence", "Offender given community sentence", 
                                                                    "Offender ordered to pay compensation", "Offender fined", "Offender given conditional discharge", "Offender deprived of property", 
                                                                    "Offender given absolute discharge"]), True, False)

# Remove all columns that are not required.
df_all.drop(["Crime ID", "Context", "Reported by", "Falls within", "Month", "Last outcome category"], axis=1, inplace=True)

# Remove all rows that contain Na's.
df_all.dropna(inplace = True)

# Get are targets values
y = df_all["prosecuted"]

# Remover the traget from the data set.
df_all.drop(["prosecuted"], axis=1, inplace=True)

# %%
# Need to fill in the Na values. 
# df_all[["Longitude", "Latitude"]] = df_all[["Longitude", "Latitude"]].fillna(-9999)

# %%
def create_column_transformer(df):
    # This created a column transformer object that contains a number of encoders that will allow for
    # data to be passed to the object and then encoded.
    columns = []
    counter = 0
    for cols in df.columns.values:
        if df_all[cols].dtype == np.float64 or df_all[cols].dtype == np.int64:
            columns.append((cols, StandardScaler(), [counter]))
        else:
            columns.append((cols, OneHotEncoder(handle_unknown='ignore'), [counter]))
        counter = counter + 1 
        
    ct = ColumnTransformer(columns, remainder='passthrough')
    ct.fit(df)
    return ct

# %%
# Create the column transformer object.
ct = create_column_transformer(df_all)

# %%
# Need to split the data up in to test and train sets
X_train, X_test, y_train, y_test = train_test_split(df_all, y, test_size=0.3)

# Create a sklearn pipeline to use in the gridsearch
pipe = Pipeline([('sampling', RandomOverSampler()), ('transform', ct), ('rfc', RandomForestClassifier(n_jobs=-1))])

# %%
# Create the parameter grid used for the grid search.

param_grid = {
    'rfc__max_depth': [i for i in range(6, 14, 1)],
    'rfc__n_estimators': [i for i in range(100, 700, 100)]
}

# %%
# Create the grid search object with a 5 fold stratified k fold.
clf = GridSearchCV(pipe, param_grid, verbose=5, scoring='f1_weighted')

# %%
_ = clf.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# [CV] rfc__max_depth=6, rfc__n_estimators=100 .........................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  rfc__max_depth=6, rfc__n_estimators=100, score=0.887, total=   3.9s
# [CV] rfc__max_depth=6, rfc__n_estimators=100 .........................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    3.8s remaining:    0.0s
# [CV]  rfc__max_depth=6, rfc__n_estimators=100, score=0.893, total=   2.1s
# [CV] rfc__max_depth=6, rfc__n_estimators=100 .........................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    5.9s remaining:    0.0s
# [CV]  rfc__max_depth=6, rfc__n_estimators=100, score=0.891, total=   2.3s
# [CV] rfc__max_depth=6, rfc__n_estimators=100 .........................
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    8.2s remaining:    0.0s
# [CV]  rfc__max_depth=6, rfc__n_estimators=100, score=0.895, total=   2.1s
# [CV] rfc__max_depth=6, rfc__n_estimators=100 .........................
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:   10.3s remaining:    0.0s
# [CV]  rfc__max_depth=6, rfc__n_estimators=100, score=0.889, total=   2.1s
# [CV] rfc__max_depth=6, rfc__n_estimators=200 .........................
# [CV]  rfc__max_depth=6, rfc__n_estimators=200, score=0.888, total=   3.6s
# [CV] rfc__max_depth=6, rfc__n_estimators=200 .........................
# [CV]  rfc__max_depth=6, rfc__n_estimators=200, score=0.891, total=   3.5s
# [CV] rfc__max_depth=6, rfc__n_estimators=200 .........................
# [CV]  rfc__max_depth=6, rfc__n_estimators=200, score=0.891, total=   3.6s
# [CV] rfc__max_depth=6, rfc__n_estimators=200 .........................
# [CV]  rfc__max_depth=6, rfc__n_estimators=200, score=0.894, total=   3.6s
# [CV] rfc__max_depth=6, rfc__n_estimators=200 .........................
# [CV]  rfc__max_depth=6, rfc__n_estimators=200, score=0.886, total=   3.5s
# [CV] rfc__max_depth=6, rfc__n_estimators=300 .........................
# [CV]  rfc__max_depth=6, rfc__n_estimators=300, score=0.894, total=   4.9s
# [CV] rfc__max_depth=6, rfc__n_estimators=300 .........................
# [CV]  rfc__max_depth=6, rfc__n_estimators=300, score=0.889, total=   4.9s
# [CV] rfc__max_depth=6, rfc__n_estimators=300 .........................
# [CV]  rfc__max_depth=6, rfc__n_estimators=300, score=0.888, total=   4.8s
# [CV] rfc__max_depth=6, rfc__n_estimators=300 .........................
# [CV]  rfc__max_depth=6, rfc__n_estimators=300, score=0.891, total=   5.1s
# [CV] rfc__max_depth=6, rfc__n_estimators=300 .........................
# [CV]  rfc__max_depth=6, rfc__n_estimators=300, score=0.898, total=   4.8s
# [CV] rfc__max_depth=6, rfc__n_estimators=400 .........................
# [CV]  rfc__max_depth=6, rfc__n_estimators=400, score=0.886, total=   6.2s
# [CV] rfc__max_depth=6, rfc__n_estimators=400 .........................
# [CV]  rfc__max_depth=6, rfc__n_estimators=400, score=0.878, total=   6.3s
# [CV] rfc__max_depth=6, rfc__n_estimators=400 .........................
# [CV]  rfc__max_depth=6, rfc__n_estimators=400, score=0.893, total=   6.2s
# [CV] rfc__max_depth=6, rfc__n_estimators=400 .........................
# [CV]  rfc__max_depth=6, rfc__n_estimators=400, score=0.889, total=   6.3s
# [CV] rfc__max_depth=6, rfc__n_estimators=400 .........................
# [CV]  rfc__max_depth=6, rfc__n_estimators=400, score=0.901, total=   6.4s
# [CV] rfc__max_depth=6, rfc__n_estimators=500 .........................
# [CV]  rfc__max_depth=6, rfc__n_estimators=500, score=0.899, total=   7.5s
# [CV] rfc__max_depth=6, rfc__n_estimators=500 .........................
# [CV]  rfc__max_depth=6, rfc__n_estimators=500, score=0.893, total=   8.0s
# [CV] rfc__max_depth=6, rfc__n_estimators=500 .........................
# [CV]  rfc__max_depth=6, rfc__n_estimators=500, score=0.895, total=   7.5s
# [CV] rfc__max_depth=6, rfc__n_estimators=500 .........................
# [CV]  rfc__max_depth=6, rfc__n_estimators=500, score=0.890, total=   7.8s
# [CV] rfc__max_depth=6, rfc__n_estimators=500 .........................
# [CV]  rfc__max_depth=6, rfc__n_estimators=500, score=0.896, total=   7.4s
# [CV] rfc__max_depth=6, rfc__n_estimators=600 .........................
# [CV]  rfc__max_depth=6, rfc__n_estimators=600, score=0.888, total=   8.9s
# [CV] rfc__max_depth=6, rfc__n_estimators=600 .........................
# [CV]  rfc__max_depth=6, rfc__n_estimators=600, score=0.889, total=   9.0s
# [CV] rfc__max_depth=6, rfc__n_estimators=600 .........................
# [CV]  rfc__max_depth=6, rfc__n_estimators=600, score=0.892, total=   9.0s
# [CV] rfc__max_depth=6, rfc__n_estimators=600 .........................
# [CV]  rfc__max_depth=6, rfc__n_estimators=600, score=0.889, total=   9.0s
# [CV] rfc__max_depth=6, rfc__n_estimators=600 .........................
# [CV]  rfc__max_depth=6, rfc__n_estimators=600, score=0.893, total=   8.9s
# [CV] rfc__max_depth=7, rfc__n_estimators=100 .........................
# [CV]  rfc__max_depth=7, rfc__n_estimators=100, score=0.900, total=   2.6s
# [CV] rfc__max_depth=7, rfc__n_estimators=100 .........................
# [CV]  rfc__max_depth=7, rfc__n_estimators=100, score=0.882, total=   2.3s
# [CV] rfc__max_depth=7, rfc__n_estimators=100 .........................
# [CV]  rfc__max_depth=7, rfc__n_estimators=100, score=0.886, total=   2.3s
# [CV] rfc__max_depth=7, rfc__n_estimators=100 .........................
# [CV]  rfc__max_depth=7, rfc__n_estimators=100, score=0.885, total=   2.3s
# [CV] rfc__max_depth=7, rfc__n_estimators=100 .........................
# [CV]  rfc__max_depth=7, rfc__n_estimators=100, score=0.901, total=   2.4s
# [CV] rfc__max_depth=7, rfc__n_estimators=200 .........................
# [CV]  rfc__max_depth=7, rfc__n_estimators=200, score=0.890, total=   3.9s
# [CV] rfc__max_depth=7, rfc__n_estimators=200 .........................
# [CV]  rfc__max_depth=7, rfc__n_estimators=200, score=0.886, total=   3.9s
# [CV] rfc__max_depth=7, rfc__n_estimators=200 .........................
# [CV]  rfc__max_depth=7, rfc__n_estimators=200, score=0.894, total=   3.9s
# [CV] rfc__max_depth=7, rfc__n_estimators=200 .........................
# [CV]  rfc__max_depth=7, rfc__n_estimators=200, score=0.882, total=   4.0s
# [CV] rfc__max_depth=7, rfc__n_estimators=200 .........................
# [CV]  rfc__max_depth=7, rfc__n_estimators=200, score=0.888, total=   3.9s
# [CV] rfc__max_depth=7, rfc__n_estimators=300 .........................
# [CV]  rfc__max_depth=7, rfc__n_estimators=300, score=0.895, total=   5.4s
# [CV] rfc__max_depth=7, rfc__n_estimators=300 .........................
# [CV]  rfc__max_depth=7, rfc__n_estimators=300, score=0.895, total=   5.6s
# [CV] rfc__max_depth=7, rfc__n_estimators=300 .........................
# [CV]  rfc__max_depth=7, rfc__n_estimators=300, score=0.892, total=   5.4s
# [CV] rfc__max_depth=7, rfc__n_estimators=300 .........................
# [CV]  rfc__max_depth=7, rfc__n_estimators=300, score=0.894, total=   5.5s
# [CV] rfc__max_depth=7, rfc__n_estimators=300 .........................
# [CV]  rfc__max_depth=7, rfc__n_estimators=300, score=0.893, total=   5.4s
# [CV] rfc__max_depth=7, rfc__n_estimators=400 .........................
# [CV]  rfc__max_depth=7, rfc__n_estimators=400, score=0.889, total=   6.9s
# [CV] rfc__max_depth=7, rfc__n_estimators=400 .........................
# [CV]  rfc__max_depth=7, rfc__n_estimators=400, score=0.891, total=   7.4s
# [CV] rfc__max_depth=7, rfc__n_estimators=400 .........................
# [CV]  rfc__max_depth=7, rfc__n_estimators=400, score=0.889, total=   7.1s
# [CV] rfc__max_depth=7, rfc__n_estimators=400 .........................
# [CV]  rfc__max_depth=7, rfc__n_estimators=400, score=0.890, total=   7.1s
# [CV] rfc__max_depth=7, rfc__n_estimators=400 .........................
# [CV]  rfc__max_depth=7, rfc__n_estimators=400, score=0.898, total=   7.2s
# [CV] rfc__max_depth=7, rfc__n_estimators=500 .........................
# [CV]  rfc__max_depth=7, rfc__n_estimators=500, score=0.892, total=   8.5s
# [CV] rfc__max_depth=7, rfc__n_estimators=500 .........................
# [CV]  rfc__max_depth=7, rfc__n_estimators=500, score=0.893, total=   8.8s
# [CV] rfc__max_depth=7, rfc__n_estimators=500 .........................
# [CV]  rfc__max_depth=7, rfc__n_estimators=500, score=0.892, total=   8.9s
# [CV] rfc__max_depth=7, rfc__n_estimators=500 .........................
# [CV]  rfc__max_depth=7, rfc__n_estimators=500, score=0.895, total=   8.6s
# [CV] rfc__max_depth=7, rfc__n_estimators=500 .........................
# [CV]  rfc__max_depth=7, rfc__n_estimators=500, score=0.898, total=   8.6s
# [CV] rfc__max_depth=7, rfc__n_estimators=600 .........................
# [CV]  rfc__max_depth=7, rfc__n_estimators=600, score=0.897, total=  10.5s
# [CV] rfc__max_depth=7, rfc__n_estimators=600 .........................
# [CV]  rfc__max_depth=7, rfc__n_estimators=600, score=0.887, total=  10.2s
# [CV] rfc__max_depth=7, rfc__n_estimators=600 .........................
# [CV]  rfc__max_depth=7, rfc__n_estimators=600, score=0.895, total=  10.3s
# [CV] rfc__max_depth=7, rfc__n_estimators=600 .........................
# [CV]  rfc__max_depth=7, rfc__n_estimators=600, score=0.888, total=  10.1s
# [CV] rfc__max_depth=7, rfc__n_estimators=600 .........................
# [CV]  rfc__max_depth=7, rfc__n_estimators=600, score=0.896, total=  10.0s
# [CV] rfc__max_depth=8, rfc__n_estimators=100 .........................
# [CV]  rfc__max_depth=8, rfc__n_estimators=100, score=0.896, total=   2.5s
# [CV] rfc__max_depth=8, rfc__n_estimators=100 .........................
# [CV]  rfc__max_depth=8, rfc__n_estimators=100, score=0.888, total=   2.5s
# [CV] rfc__max_depth=8, rfc__n_estimators=100 .........................
# [CV]  rfc__max_depth=8, rfc__n_estimators=100, score=0.897, total=   2.6s
# [CV] rfc__max_depth=8, rfc__n_estimators=100 .........................
# [CV]  rfc__max_depth=8, rfc__n_estimators=100, score=0.902, total=   2.5s
# [CV] rfc__max_depth=8, rfc__n_estimators=100 .........................
# [CV]  rfc__max_depth=8, rfc__n_estimators=100, score=0.886, total=   2.4s
# [CV] rfc__max_depth=8, rfc__n_estimators=200 .........................
# [CV]  rfc__max_depth=8, rfc__n_estimators=200, score=0.891, total=   4.4s
# [CV] rfc__max_depth=8, rfc__n_estimators=200 .........................
# [CV]  rfc__max_depth=8, rfc__n_estimators=200, score=0.890, total=   4.3s
# [CV] rfc__max_depth=8, rfc__n_estimators=200 .........................
# [CV]  rfc__max_depth=8, rfc__n_estimators=200, score=0.897, total=   4.6s
# [CV] rfc__max_depth=8, rfc__n_estimators=200 .........................
# [CV]  rfc__max_depth=8, rfc__n_estimators=200, score=0.893, total=   4.5s
# [CV] rfc__max_depth=8, rfc__n_estimators=200 .........................
# [CV]  rfc__max_depth=8, rfc__n_estimators=200, score=0.896, total=   4.2s
# [CV] rfc__max_depth=8, rfc__n_estimators=300 .........................
# [CV]  rfc__max_depth=8, rfc__n_estimators=300, score=0.901, total=   6.4s
# [CV] rfc__max_depth=8, rfc__n_estimators=300 .........................
# [CV]  rfc__max_depth=8, rfc__n_estimators=300, score=0.895, total=   6.4s
# [CV] rfc__max_depth=8, rfc__n_estimators=300 .........................
# [CV]  rfc__max_depth=8, rfc__n_estimators=300, score=0.901, total=   6.3s
# [CV] rfc__max_depth=8, rfc__n_estimators=300 .........................
# [CV]  rfc__max_depth=8, rfc__n_estimators=300, score=0.894, total=   6.2s
# [CV] rfc__max_depth=8, rfc__n_estimators=300 .........................
# [CV]  rfc__max_depth=8, rfc__n_estimators=300, score=0.896, total=   6.4s
# [CV] rfc__max_depth=8, rfc__n_estimators=400 .........................
# [CV]  rfc__max_depth=8, rfc__n_estimators=400, score=0.893, total=   7.9s
# [CV] rfc__max_depth=8, rfc__n_estimators=400 .........................
# [CV]  rfc__max_depth=8, rfc__n_estimators=400, score=0.891, total=   8.0s
# [CV] rfc__max_depth=8, rfc__n_estimators=400 .........................
# [CV]  rfc__max_depth=8, rfc__n_estimators=400, score=0.894, total=   8.2s
# [CV] rfc__max_depth=8, rfc__n_estimators=400 .........................
# [CV]  rfc__max_depth=8, rfc__n_estimators=400, score=0.895, total=   8.2s
# [CV] rfc__max_depth=8, rfc__n_estimators=400 .........................
# [CV]  rfc__max_depth=8, rfc__n_estimators=400, score=0.894, total=   7.8s
# [CV] rfc__max_depth=8, rfc__n_estimators=500 .........................
# [CV]  rfc__max_depth=8, rfc__n_estimators=500, score=0.893, total=   9.7s
# [CV] rfc__max_depth=8, rfc__n_estimators=500 .........................
# [CV]  rfc__max_depth=8, rfc__n_estimators=500, score=0.891, total=  10.0s
# [CV] rfc__max_depth=8, rfc__n_estimators=500 .........................
# [CV]  rfc__max_depth=8, rfc__n_estimators=500, score=0.893, total=  10.1s
# [CV] rfc__max_depth=8, rfc__n_estimators=500 .........................
# [CV]  rfc__max_depth=8, rfc__n_estimators=500, score=0.894, total=   9.9s
# [CV] rfc__max_depth=8, rfc__n_estimators=500 .........................
# [CV]  rfc__max_depth=8, rfc__n_estimators=500, score=0.901, total=   9.4s
# [CV] rfc__max_depth=8, rfc__n_estimators=600 .........................
# [CV]  rfc__max_depth=8, rfc__n_estimators=600, score=0.894, total=  11.4s
# [CV] rfc__max_depth=8, rfc__n_estimators=600 .........................
# [CV]  rfc__max_depth=8, rfc__n_estimators=600, score=0.894, total=  11.8s
# [CV] rfc__max_depth=8, rfc__n_estimators=600 .........................
# [CV]  rfc__max_depth=8, rfc__n_estimators=600, score=0.891, total=  12.0s
# [CV] rfc__max_depth=8, rfc__n_estimators=600 .........................
# [CV]  rfc__max_depth=8, rfc__n_estimators=600, score=0.897, total=  11.7s
# [CV] rfc__max_depth=8, rfc__n_estimators=600 .........................
# [CV]  rfc__max_depth=8, rfc__n_estimators=600, score=0.893, total=  11.6s
# [CV] rfc__max_depth=9, rfc__n_estimators=100 .........................
# [CV]  rfc__max_depth=9, rfc__n_estimators=100, score=0.889, total=   3.1s
# [CV] rfc__max_depth=9, rfc__n_estimators=100 .........................
# [CV]  rfc__max_depth=9, rfc__n_estimators=100, score=0.890, total=   2.9s
# [CV] rfc__max_depth=9, rfc__n_estimators=100 .........................
# [CV]  rfc__max_depth=9, rfc__n_estimators=100, score=0.893, total=   3.0s
# [CV] rfc__max_depth=9, rfc__n_estimators=100 .........................
# [CV]  rfc__max_depth=9, rfc__n_estimators=100, score=0.906, total=   3.1s
# [CV] rfc__max_depth=9, rfc__n_estimators=100 .........................
# [CV]  rfc__max_depth=9, rfc__n_estimators=100, score=0.903, total=   3.0s
# [CV] rfc__max_depth=9, rfc__n_estimators=200 .........................
# [CV]  rfc__max_depth=9, rfc__n_estimators=200, score=0.894, total=   5.0s
# [CV] rfc__max_depth=9, rfc__n_estimators=200 .........................
# [CV]  rfc__max_depth=9, rfc__n_estimators=200, score=0.895, total=   5.1s
# [CV] rfc__max_depth=9, rfc__n_estimators=200 .........................
# [CV]  rfc__max_depth=9, rfc__n_estimators=200, score=0.897, total=   5.2s
# [CV] rfc__max_depth=9, rfc__n_estimators=200 .........................
# [CV]  rfc__max_depth=9, rfc__n_estimators=200, score=0.906, total=   4.9s
# [CV] rfc__max_depth=9, rfc__n_estimators=200 .........................
# [CV]  rfc__max_depth=9, rfc__n_estimators=200, score=0.898, total=   4.7s
# [CV] rfc__max_depth=9, rfc__n_estimators=300 .........................
# [CV]  rfc__max_depth=9, rfc__n_estimators=300, score=0.895, total=   6.8s
# [CV] rfc__max_depth=9, rfc__n_estimators=300 .........................
# [CV]  rfc__max_depth=9, rfc__n_estimators=300, score=0.896, total=   7.1s
# [CV] rfc__max_depth=9, rfc__n_estimators=300 .........................
# [CV]  rfc__max_depth=9, rfc__n_estimators=300, score=0.895, total=   7.1s
# [CV] rfc__max_depth=9, rfc__n_estimators=300 .........................
# [CV]  rfc__max_depth=9, rfc__n_estimators=300, score=0.893, total=   7.3s
# [CV] rfc__max_depth=9, rfc__n_estimators=300 .........................
# [CV]  rfc__max_depth=9, rfc__n_estimators=300, score=0.899, total=   6.9s
# [CV] rfc__max_depth=9, rfc__n_estimators=400 .........................
# [CV]  rfc__max_depth=9, rfc__n_estimators=400, score=0.895, total=   9.2s
# [CV] rfc__max_depth=9, rfc__n_estimators=400 .........................
# [CV]  rfc__max_depth=9, rfc__n_estimators=400, score=0.892, total=   9.2s
# [CV] rfc__max_depth=9, rfc__n_estimators=400 .........................
# [CV]  rfc__max_depth=9, rfc__n_estimators=400, score=0.900, total=   9.4s
# [CV] rfc__max_depth=9, rfc__n_estimators=400 .........................
# [CV]  rfc__max_depth=9, rfc__n_estimators=400, score=0.896, total=   9.1s
# [CV] rfc__max_depth=9, rfc__n_estimators=400 .........................
# [CV]  rfc__max_depth=9, rfc__n_estimators=400, score=0.898, total=   9.3s
# [CV] rfc__max_depth=9, rfc__n_estimators=500 .........................
# [CV]  rfc__max_depth=9, rfc__n_estimators=500, score=0.895, total=  11.2s
# [CV] rfc__max_depth=9, rfc__n_estimators=500 .........................
# [CV]  rfc__max_depth=9, rfc__n_estimators=500, score=0.893, total=  11.3s
# [CV] rfc__max_depth=9, rfc__n_estimators=500 .........................
# [CV]  rfc__max_depth=9, rfc__n_estimators=500, score=0.897, total=  11.5s
# [CV] rfc__max_depth=9, rfc__n_estimators=500 .........................
# [CV]  rfc__max_depth=9, rfc__n_estimators=500, score=0.897, total=  11.1s
# [CV] rfc__max_depth=9, rfc__n_estimators=500 .........................
# [CV]  rfc__max_depth=9, rfc__n_estimators=500, score=0.898, total=  11.2s
# [CV] rfc__max_depth=9, rfc__n_estimators=600 .........................
# [CV]  rfc__max_depth=9, rfc__n_estimators=600, score=0.894, total=  12.9s
# [CV] rfc__max_depth=9, rfc__n_estimators=600 .........................
# [CV]  rfc__max_depth=9, rfc__n_estimators=600, score=0.893, total=  13.3s
# [CV] rfc__max_depth=9, rfc__n_estimators=600 .........................
# [CV]  rfc__max_depth=9, rfc__n_estimators=600, score=0.897, total=  13.2s
# [CV] rfc__max_depth=9, rfc__n_estimators=600 .........................
# [CV]  rfc__max_depth=9, rfc__n_estimators=600, score=0.894, total=  13.2s
# [CV] rfc__max_depth=9, rfc__n_estimators=600 .........................
# [CV]  rfc__max_depth=9, rfc__n_estimators=600, score=0.897, total=  12.9s
# [CV] rfc__max_depth=10, rfc__n_estimators=100 ........................
# [CV]  rfc__max_depth=10, rfc__n_estimators=100, score=0.896, total=   3.1s
# [CV] rfc__max_depth=10, rfc__n_estimators=100 ........................
# [CV]  rfc__max_depth=10, rfc__n_estimators=100, score=0.892, total=   3.4s
# [CV] rfc__max_depth=10, rfc__n_estimators=100 ........................
# [CV]  rfc__max_depth=10, rfc__n_estimators=100, score=0.902, total=   3.3s
# [CV] rfc__max_depth=10, rfc__n_estimators=100 ........................
# [CV]  rfc__max_depth=10, rfc__n_estimators=100, score=0.900, total=   3.3s
# [CV] rfc__max_depth=10, rfc__n_estimators=100 ........................
# [CV]  rfc__max_depth=10, rfc__n_estimators=100, score=0.899, total=   3.1s
# [CV] rfc__max_depth=10, rfc__n_estimators=200 ........................
# [CV]  rfc__max_depth=10, rfc__n_estimators=200, score=0.898, total=   5.5s
# [CV] rfc__max_depth=10, rfc__n_estimators=200 ........................
# [CV]  rfc__max_depth=10, rfc__n_estimators=200, score=0.895, total=   5.6s
# [CV] rfc__max_depth=10, rfc__n_estimators=200 ........................
# [CV]  rfc__max_depth=10, rfc__n_estimators=200, score=0.898, total=   5.8s
# [CV] rfc__max_depth=10, rfc__n_estimators=200 ........................
# [CV]  rfc__max_depth=10, rfc__n_estimators=200, score=0.900, total=   5.7s
# [CV] rfc__max_depth=10, rfc__n_estimators=200 ........................
# [CV]  rfc__max_depth=10, rfc__n_estimators=200, score=0.898, total=   5.5s
# [CV] rfc__max_depth=10, rfc__n_estimators=300 ........................
# [CV]  rfc__max_depth=10, rfc__n_estimators=300, score=0.903, total=   8.2s
# [CV] rfc__max_depth=10, rfc__n_estimators=300 ........................
# [CV]  rfc__max_depth=10, rfc__n_estimators=300, score=0.897, total=   8.0s
# [CV] rfc__max_depth=10, rfc__n_estimators=300 ........................
# [CV]  rfc__max_depth=10, rfc__n_estimators=300, score=0.904, total=   8.2s
# [CV] rfc__max_depth=10, rfc__n_estimators=300 ........................
# [CV]  rfc__max_depth=10, rfc__n_estimators=300, score=0.899, total=   8.2s
# [CV] rfc__max_depth=10, rfc__n_estimators=300 ........................
# [CV]  rfc__max_depth=10, rfc__n_estimators=300, score=0.898, total=   7.9s
# [CV] rfc__max_depth=10, rfc__n_estimators=400 ........................
# [CV]  rfc__max_depth=10, rfc__n_estimators=400, score=0.899, total=  10.4s
# [CV] rfc__max_depth=10, rfc__n_estimators=400 ........................
# [CV]  rfc__max_depth=10, rfc__n_estimators=400, score=0.899, total=  10.6s
# [CV] rfc__max_depth=10, rfc__n_estimators=400 ........................
# [CV]  rfc__max_depth=10, rfc__n_estimators=400, score=0.901, total=  10.6s
# [CV] rfc__max_depth=10, rfc__n_estimators=400 ........................
# [CV]  rfc__max_depth=10, rfc__n_estimators=400, score=0.901, total=  10.8s
# [CV] rfc__max_depth=10, rfc__n_estimators=400 ........................
# [CV]  rfc__max_depth=10, rfc__n_estimators=400, score=0.901, total=  10.1s
# [CV] rfc__max_depth=10, rfc__n_estimators=500 ........................
# [CV]  rfc__max_depth=10, rfc__n_estimators=500, score=0.899, total=  12.7s
# [CV] rfc__max_depth=10, rfc__n_estimators=500 ........................
# [CV]  rfc__max_depth=10, rfc__n_estimators=500, score=0.896, total=  13.1s
# [CV] rfc__max_depth=10, rfc__n_estimators=500 ........................
# [CV]  rfc__max_depth=10, rfc__n_estimators=500, score=0.899, total=  13.1s
# [CV] rfc__max_depth=10, rfc__n_estimators=500 ........................
# [CV]  rfc__max_depth=10, rfc__n_estimators=500, score=0.904, total=  13.5s
# [CV] rfc__max_depth=10, rfc__n_estimators=500 ........................
# [CV]  rfc__max_depth=10, rfc__n_estimators=500, score=0.902, total=  12.4s
# [CV] rfc__max_depth=10, rfc__n_estimators=600 ........................
# [CV]  rfc__max_depth=10, rfc__n_estimators=600, score=0.898, total=  15.2s
# [CV] rfc__max_depth=10, rfc__n_estimators=600 ........................
# [CV]  rfc__max_depth=10, rfc__n_estimators=600, score=0.897, total=  15.4s
# [CV] rfc__max_depth=10, rfc__n_estimators=600 ........................
# [CV]  rfc__max_depth=10, rfc__n_estimators=600, score=0.902, total=  15.5s
# [CV] rfc__max_depth=10, rfc__n_estimators=600 ........................
# [CV]  rfc__max_depth=10, rfc__n_estimators=600, score=0.902, total=  15.7s
# [CV] rfc__max_depth=10, rfc__n_estimators=600 ........................
# [CV]  rfc__max_depth=10, rfc__n_estimators=600, score=0.901, total=  15.3s
# [CV] rfc__max_depth=11, rfc__n_estimators=100 ........................
# [CV]  rfc__max_depth=11, rfc__n_estimators=100, score=0.908, total=   3.5s
# [CV] rfc__max_depth=11, rfc__n_estimators=100 ........................
# [CV]  rfc__max_depth=11, rfc__n_estimators=100, score=0.902, total=   3.7s
# [CV] rfc__max_depth=11, rfc__n_estimators=100 ........................
# [CV]  rfc__max_depth=11, rfc__n_estimators=100, score=0.899, total=   3.6s
# [CV] rfc__max_depth=11, rfc__n_estimators=100 ........................
# [CV]  rfc__max_depth=11, rfc__n_estimators=100, score=0.903, total=   3.6s
# [CV] rfc__max_depth=11, rfc__n_estimators=100 ........................
# [CV]  rfc__max_depth=11, rfc__n_estimators=100, score=0.902, total=   3.5s
# [CV] rfc__max_depth=11, rfc__n_estimators=200 ........................
# [CV]  rfc__max_depth=11, rfc__n_estimators=200, score=0.908, total=   6.1s
# [CV] rfc__max_depth=11, rfc__n_estimators=200 ........................
# [CV]  rfc__max_depth=11, rfc__n_estimators=200, score=0.898, total=   6.6s
# [CV] rfc__max_depth=11, rfc__n_estimators=200 ........................
# [CV]  rfc__max_depth=11, rfc__n_estimators=200, score=0.903, total=   6.2s
# [CV] rfc__max_depth=11, rfc__n_estimators=200 ........................
# [CV]  rfc__max_depth=11, rfc__n_estimators=200, score=0.902, total=   6.5s
# [CV] rfc__max_depth=11, rfc__n_estimators=200 ........................
# [CV]  rfc__max_depth=11, rfc__n_estimators=200, score=0.897, total=   6.3s
# [CV] rfc__max_depth=11, rfc__n_estimators=300 ........................
# [CV]  rfc__max_depth=11, rfc__n_estimators=300, score=0.900, total=   9.0s
# [CV] rfc__max_depth=11, rfc__n_estimators=300 ........................
# [CV]  rfc__max_depth=11, rfc__n_estimators=300, score=0.897, total=   9.4s
# [CV] rfc__max_depth=11, rfc__n_estimators=300 ........................
# [CV]  rfc__max_depth=11, rfc__n_estimators=300, score=0.903, total=   9.4s
# [CV] rfc__max_depth=11, rfc__n_estimators=300 ........................
# [CV]  rfc__max_depth=11, rfc__n_estimators=300, score=0.910, total=   9.5s
# [CV] rfc__max_depth=11, rfc__n_estimators=300 ........................
# [CV]  rfc__max_depth=11, rfc__n_estimators=300, score=0.903, total=   8.8s
# [CV] rfc__max_depth=11, rfc__n_estimators=400 ........................
# [CV]  rfc__max_depth=11, rfc__n_estimators=400, score=0.901, total=  12.0s
# [CV] rfc__max_depth=11, rfc__n_estimators=400 ........................
# [CV]  rfc__max_depth=11, rfc__n_estimators=400, score=0.897, total=  12.2s
# [CV] rfc__max_depth=11, rfc__n_estimators=400 ........................
# [CV]  rfc__max_depth=11, rfc__n_estimators=400, score=0.901, total=  12.0s
# [CV] rfc__max_depth=11, rfc__n_estimators=400 ........................
# [CV]  rfc__max_depth=11, rfc__n_estimators=400, score=0.900, total=  12.7s
# [CV] rfc__max_depth=11, rfc__n_estimators=400 ........................
# [CV]  rfc__max_depth=11, rfc__n_estimators=400, score=0.904, total=  12.0s
# [CV] rfc__max_depth=11, rfc__n_estimators=500 ........................
# [CV]  rfc__max_depth=11, rfc__n_estimators=500, score=0.907, total=  14.5s
# [CV] rfc__max_depth=11, rfc__n_estimators=500 ........................
# [CV]  rfc__max_depth=11, rfc__n_estimators=500, score=0.901, total=  15.2s
# [CV] rfc__max_depth=11, rfc__n_estimators=500 ........................
# [CV]  rfc__max_depth=11, rfc__n_estimators=500, score=0.905, total=  14.7s
# [CV] rfc__max_depth=11, rfc__n_estimators=500 ........................
# [CV]  rfc__max_depth=11, rfc__n_estimators=500, score=0.904, total=  15.1s
# [CV] rfc__max_depth=11, rfc__n_estimators=500 ........................
# [CV]  rfc__max_depth=11, rfc__n_estimators=500, score=0.904, total=  14.5s
# [CV] rfc__max_depth=11, rfc__n_estimators=600 ........................
# [CV]  rfc__max_depth=11, rfc__n_estimators=600, score=0.898, total=  18.4s
# [CV] rfc__max_depth=11, rfc__n_estimators=600 ........................
# [CV]  rfc__max_depth=11, rfc__n_estimators=600, score=0.898, total=  18.2s
# [CV] rfc__max_depth=11, rfc__n_estimators=600 ........................
# [CV]  rfc__max_depth=11, rfc__n_estimators=600, score=0.903, total=  17.9s
# [CV] rfc__max_depth=11, rfc__n_estimators=600 ........................
# [CV]  rfc__max_depth=11, rfc__n_estimators=600, score=0.903, total=  18.5s
# [CV] rfc__max_depth=11, rfc__n_estimators=600 ........................
# [CV]  rfc__max_depth=11, rfc__n_estimators=600, score=0.903, total=  17.7s
# [CV] rfc__max_depth=12, rfc__n_estimators=100 ........................
# [CV]  rfc__max_depth=12, rfc__n_estimators=100, score=0.903, total=   4.0s
# [CV] rfc__max_depth=12, rfc__n_estimators=100 ........................
# [CV]  rfc__max_depth=12, rfc__n_estimators=100, score=0.908, total=   4.3s
# [CV] rfc__max_depth=12, rfc__n_estimators=100 ........................
# [CV]  rfc__max_depth=12, rfc__n_estimators=100, score=0.897, total=   4.0s
# [CV] rfc__max_depth=12, rfc__n_estimators=100 ........................
# [CV]  rfc__max_depth=12, rfc__n_estimators=100, score=0.904, total=   4.4s
# [CV] rfc__max_depth=12, rfc__n_estimators=100 ........................
# [CV]  rfc__max_depth=12, rfc__n_estimators=100, score=0.902, total=   3.9s
# [CV] rfc__max_depth=12, rfc__n_estimators=200 ........................
# [CV]  rfc__max_depth=12, rfc__n_estimators=200, score=0.911, total=   7.5s
# [CV] rfc__max_depth=12, rfc__n_estimators=200 ........................
# [CV]  rfc__max_depth=12, rfc__n_estimators=200, score=0.900, total=   7.4s
# [CV] rfc__max_depth=12, rfc__n_estimators=200 ........................
# [CV]  rfc__max_depth=12, rfc__n_estimators=200, score=0.901, total=   7.3s
# [CV] rfc__max_depth=12, rfc__n_estimators=200 ........................
# [CV]  rfc__max_depth=12, rfc__n_estimators=200, score=0.904, total=   7.5s
# [CV] rfc__max_depth=12, rfc__n_estimators=200 ........................
# [CV]  rfc__max_depth=12, rfc__n_estimators=200, score=0.903, total=   7.3s
# [CV] rfc__max_depth=12, rfc__n_estimators=300 ........................
# [CV]  rfc__max_depth=12, rfc__n_estimators=300, score=0.899, total=  10.8s
# [CV] rfc__max_depth=12, rfc__n_estimators=300 ........................
# [CV]  rfc__max_depth=12, rfc__n_estimators=300, score=0.899, total=  10.9s
# [CV] rfc__max_depth=12, rfc__n_estimators=300 ........................
# [CV]  rfc__max_depth=12, rfc__n_estimators=300, score=0.901, total=  11.4s
# [CV] rfc__max_depth=12, rfc__n_estimators=300 ........................
# [CV]  rfc__max_depth=12, rfc__n_estimators=300, score=0.906, total=  10.8s
# [CV] rfc__max_depth=12, rfc__n_estimators=300 ........................
# [CV]  rfc__max_depth=12, rfc__n_estimators=300, score=0.903, total=  10.7s
# [CV] rfc__max_depth=12, rfc__n_estimators=400 ........................
# [CV]  rfc__max_depth=12, rfc__n_estimators=400, score=0.905, total=  14.3s
# [CV] rfc__max_depth=12, rfc__n_estimators=400 ........................
# [CV]  rfc__max_depth=12, rfc__n_estimators=400, score=0.898, total=  14.6s
# [CV] rfc__max_depth=12, rfc__n_estimators=400 ........................
# [CV]  rfc__max_depth=12, rfc__n_estimators=400, score=0.903, total=  14.1s
# [CV] rfc__max_depth=12, rfc__n_estimators=400 ........................
# [CV]  rfc__max_depth=12, rfc__n_estimators=400, score=0.904, total=  14.3s
# [CV] rfc__max_depth=12, rfc__n_estimators=400 ........................
# [CV]  rfc__max_depth=12, rfc__n_estimators=400, score=0.906, total=  13.4s
# [CV] rfc__max_depth=12, rfc__n_estimators=500 ........................
# [CV]  rfc__max_depth=12, rfc__n_estimators=500, score=0.902, total=  17.0s
# [CV] rfc__max_depth=12, rfc__n_estimators=500 ........................
# [CV]  rfc__max_depth=12, rfc__n_estimators=500, score=0.900, total=  17.4s
# [CV] rfc__max_depth=12, rfc__n_estimators=500 ........................
# [CV]  rfc__max_depth=12, rfc__n_estimators=500, score=0.906, total=  18.1s
# [CV] rfc__max_depth=12, rfc__n_estimators=500 ........................
# [CV]  rfc__max_depth=12, rfc__n_estimators=500, score=0.902, total=  17.7s
# [CV] rfc__max_depth=12, rfc__n_estimators=500 ........................
# [CV]  rfc__max_depth=12, rfc__n_estimators=500, score=0.905, total=  16.8s
# [CV] rfc__max_depth=12, rfc__n_estimators=600 ........................
# [CV]  rfc__max_depth=12, rfc__n_estimators=600, score=0.903, total=  20.8s
# [CV] rfc__max_depth=12, rfc__n_estimators=600 ........................
# [CV]  rfc__max_depth=12, rfc__n_estimators=600, score=0.899, total=  21.3s
# [CV] rfc__max_depth=12, rfc__n_estimators=600 ........................
# [CV]  rfc__max_depth=12, rfc__n_estimators=600, score=0.907, total=  21.0s
# [CV] rfc__max_depth=12, rfc__n_estimators=600 ........................
# [CV]  rfc__max_depth=12, rfc__n_estimators=600, score=0.902, total=  20.9s
# [CV] rfc__max_depth=12, rfc__n_estimators=600 ........................
# [CV]  rfc__max_depth=12, rfc__n_estimators=600, score=0.905, total=  20.0s
# [CV] rfc__max_depth=13, rfc__n_estimators=100 ........................
# [CV]  rfc__max_depth=13, rfc__n_estimators=100, score=0.901, total=   4.5s
# [CV] rfc__max_depth=13, rfc__n_estimators=100 ........................
# [CV]  rfc__max_depth=13, rfc__n_estimators=100, score=0.903, total=   4.6s
# [CV] rfc__max_depth=13, rfc__n_estimators=100 ........................
# [CV]  rfc__max_depth=13, rfc__n_estimators=100, score=0.912, total=   4.4s
# [CV] rfc__max_depth=13, rfc__n_estimators=100 ........................
# [CV]  rfc__max_depth=13, rfc__n_estimators=100, score=0.909, total=   4.5s
# [CV] rfc__max_depth=13, rfc__n_estimators=100 ........................
# [CV]  rfc__max_depth=13, rfc__n_estimators=100, score=0.906, total=   4.4s
# [CV] rfc__max_depth=13, rfc__n_estimators=200 ........................
# [CV]  rfc__max_depth=13, rfc__n_estimators=200, score=0.905, total=   8.5s
# [CV] rfc__max_depth=13, rfc__n_estimators=200 ........................
# [CV]  rfc__max_depth=13, rfc__n_estimators=200, score=0.898, total=   8.7s
# [CV] rfc__max_depth=13, rfc__n_estimators=200 ........................
# [CV]  rfc__max_depth=13, rfc__n_estimators=200, score=0.907, total=   8.4s
# [CV] rfc__max_depth=13, rfc__n_estimators=200 ........................
# [CV]  rfc__max_depth=13, rfc__n_estimators=200, score=0.905, total=   8.5s
# [CV] rfc__max_depth=13, rfc__n_estimators=200 ........................
# [CV]  rfc__max_depth=13, rfc__n_estimators=200, score=0.906, total=   8.1s
# [CV] rfc__max_depth=13, rfc__n_estimators=300 ........................
# [CV]  rfc__max_depth=13, rfc__n_estimators=300, score=0.906, total=  12.2s
# [CV] rfc__max_depth=13, rfc__n_estimators=300 ........................
# [CV]  rfc__max_depth=13, rfc__n_estimators=300, score=0.896, total=  12.3s
# [CV] rfc__max_depth=13, rfc__n_estimators=300 ........................
# [CV]  rfc__max_depth=13, rfc__n_estimators=300, score=0.906, total=  12.5s
# [CV] rfc__max_depth=13, rfc__n_estimators=300 ........................
# [CV]  rfc__max_depth=13, rfc__n_estimators=300, score=0.904, total=  12.5s
# [CV] rfc__max_depth=13, rfc__n_estimators=300 ........................
# [CV]  rfc__max_depth=13, rfc__n_estimators=300, score=0.905, total=  11.8s
# [CV] rfc__max_depth=13, rfc__n_estimators=400 ........................
# [CV]  rfc__max_depth=13, rfc__n_estimators=400, score=0.906, total=  15.7s
# [CV] rfc__max_depth=13, rfc__n_estimators=400 ........................
# [CV]  rfc__max_depth=13, rfc__n_estimators=400, score=0.902, total=  16.0s
# [CV] rfc__max_depth=13, rfc__n_estimators=400 ........................
# [CV]  rfc__max_depth=13, rfc__n_estimators=400, score=0.904, total=  15.7s
# [CV] rfc__max_depth=13, rfc__n_estimators=400 ........................
# [CV]  rfc__max_depth=13, rfc__n_estimators=400, score=0.907, total=  16.0s
# [CV] rfc__max_depth=13, rfc__n_estimators=400 ........................
# [CV]  rfc__max_depth=13, rfc__n_estimators=400, score=0.905, total=  15.5s
# [CV] rfc__max_depth=13, rfc__n_estimators=500 ........................
# [CV]  rfc__max_depth=13, rfc__n_estimators=500, score=0.904, total=  19.2s
# [CV] rfc__max_depth=13, rfc__n_estimators=500 ........................
# [CV]  rfc__max_depth=13, rfc__n_estimators=500, score=0.907, total=  20.4s
# [CV] rfc__max_depth=13, rfc__n_estimators=500 ........................
# [CV]  rfc__max_depth=13, rfc__n_estimators=500, score=0.905, total=  19.7s
# [CV] rfc__max_depth=13, rfc__n_estimators=500 ........................
# [CV]  rfc__max_depth=13, rfc__n_estimators=500, score=0.907, total=  19.6s
# [CV] rfc__max_depth=13, rfc__n_estimators=500 ........................
# [CV]  rfc__max_depth=13, rfc__n_estimators=500, score=0.906, total=  19.8s
# [CV] rfc__max_depth=13, rfc__n_estimators=600 ........................
# [CV]  rfc__max_depth=13, rfc__n_estimators=600, score=0.903, total=  23.0s
# [CV] rfc__max_depth=13, rfc__n_estimators=600 ........................
# [CV]  rfc__max_depth=13, rfc__n_estimators=600, score=0.900, total=  24.2s
# [CV] rfc__max_depth=13, rfc__n_estimators=600 ........................
# [CV]  rfc__max_depth=13, rfc__n_estimators=600, score=0.908, total=  23.6s
# [CV] rfc__max_depth=13, rfc__n_estimators=600 ........................
# [CV]  rfc__max_depth=13, rfc__n_estimators=600, score=0.907, total=  24.0s
# [CV] rfc__max_depth=13, rfc__n_estimators=600 ........................
# [CV]  rfc__max_depth=13, rfc__n_estimators=600, score=0.907, total=  23.5s
# [Parallel(n_jobs=1)]: Done 240 out of 240 | elapsed: 36.9min finished

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

# %%
# Get the prediction of for the test set
prediction = clf.predict(X_test)

# %%
# Get the Precission Recall and F1 score for the models results
print(classification_report(y_test, prediction))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.99      0.85      0.92     71838
#         True       0.04      0.59      0.08       834
#
#     accuracy                           0.84     72672
#    macro avg       0.52      0.72      0.50     72672
# weighted avg       0.98      0.84      0.91     72672

# %%
# Crerate a confusion matrix for the model to see the amount of correct and in correct anwsers
confusion_matrix(y_test, prediction)
# Out:
# array([[60908, 10930],
#        [  339,   495]], dtype=int64)
